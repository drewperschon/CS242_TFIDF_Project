# %%
import nltk
nltk.download("stopwords")

from nltk.stem import WordNetLemmatizer
nltk.download("wordnet")
nltk.download("omw-1.4")

import numpy as np
import re
import pandas as pd
import os
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Drew
# [nltk_data]     Perschon\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Drew
# [nltk_data]     Perschon\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Drew
# [nltk_data]     Perschon\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
stop_words = set(stopwords.words("english")) #stopwords download (use)
lemmatizer = WordNetLemmatizer() #lemmatizer download (use)
stemmer = PorterStemmer() #stemmer download (maybe use)

texts = [] #get docs
keys = [] #get doc words

for f in os.listdir("."): #load from folder
    if f.endswith(".txt"):
        with open(f, "r", encoding="utf-8",errors="ignore") as file:
            texts.append(file.read())
            keys.append(f)

# %%
def clean_text(text):  
    start = text.find("*** START") #removing headers and footers
    end = text.find("*** END")
    if start != -1 and end != -1:
        text = text[start:end]

    text = text.lower() #converting to lowercase
    text = re.sub(r"[^a-z\s]", " ", text) #replacing all punctuation and nonalphanumeric

    tokens = text.split() #tokenize
    tokens = [lemmatizer.lemmatize(t) for t in tokens if t not in stop_words if len(t)>2] #conditions
    
    return tokens

docs = [clean_text(t) for t in texts]
vocab = sorted(set(word for doc in docs for word in doc)) #get all total words

# %%
def freq_matrix(docs, keys, vocab):
    matrix = pd.DataFrame(0, index=keys, columns=vocab, dtype=float)

    for key, tokens in zip(keys, docs):
        for token in tokens:
            matrix.at[key, token] += 1
        matrix.loc[key] = matrix.loc[key]/len(tokens) #normalize
    return matrix

# %%
def calc_tfidf(matrix, docs, vocab):
    N = len(docs) #num of docs
    df = (matrix>0).sum(axis=0) #amount of docs containing term
    idf = np.log((1+N)/(1+df)) +1 #change when more files uploaded
    idf = pd.Series(idf, index=vocab)

    tfidf = matrix * idf
    return tfidf

# %%
matrix = freq_matrix(docs, keys, vocab)
tfidf = calc_tfidf(matrix, docs, vocab)

similar = cosine_similarity(tfidf)
sim_df = pd.DataFrame(similar, index=keys, columns=keys) #comparing each book

print("\n Similarity to BSA Handbook:\n")
print(sim_df["bsa_handbook.txt"].drop("bsa_handbook.txt").sort_values(ascending=False)) #final comparison with bsa_handbook.txt

for doc in keys:
    if doc == "bsa_handbook.txt":
        continue
    diff = tfidf.loc[doc] - tfidf.loc["bsa_handbook.txt"]
    unique = diff.sort_values(ascending=False).head(10)
    print(f"\nTop distinctive words in {doc} compared to BSA handbook:")
    print(unique)


similarities = sim_df["bsa_handbook.txt"].drop("bsa_handbook.txt").sort_values()

colors = ["purple"] * len(similarities) #regular color
colors[list(similarities.index).index(similarities.idxmax())] = "green" #top color
colors[list(similarities.index).index(similarities.idxmin())] = "red" #bottom color

plot = similarities.plot(kind="barh", figsize=[8,5], color=colors) #make a pretty bar plot
plt.title("Similarity of Scouting Aspects Compared to 1911 BSA Handbook")
plt.xlabel("Cosine Similarity")

plt.xlim(0, similarities.max() + 0.1) #expanding x axis

for i, (val, name) in enumerate(zip(similarities, similarities.index)):
    plt.text(val+0.01, i, f"{val:.4f}", va="center")

most_patch = mpatches.Patch(color="green", label="Most similar to BSA handbook") #legend
least_patch = mpatches.Patch(color="red", label="Least similar to BSA handbook")
other_patch = mpatches.Patch(color="purple", label="Other")
plt.legend(handles=[most_patch, least_patch, other_patch], loc="lower right")

plt.show()
# Out:
#  Similarity to BSA Handbook:
#
# health.txt         0.440733
# character.txt      0.417872
# survival.txt       0.417646
# leadership.txt     0.328570
# environment.txt    0.284501
# citizenship.txt    0.242490
# knots.txt          0.175799
# Name: bsa_handbook.txt, dtype: float64
#
# Top distinctive words in character.txt compared to BSA handbook:
# people         0.011856
# school         0.008707
# going          0.008651
# want           0.008275
# get            0.007060
# work           0.006999
# student        0.006844
# person         0.006776
# institution    0.006494
# year           0.006093
# dtype: float64
#
# Top distinctive words in citizenship.txt compared to BSA handbook:
# state         0.029069
# vote          0.023871
# voter         0.021031
# election      0.018707
# government    0.017121
# committee     0.015600
# court         0.013583
# convention    0.013461
# president     0.012895
# party         0.012550
# dtype: float64
#
# Top distinctive words in environment.txt compared to BSA handbook:
# specie          0.030863
# genus           0.009940
# selection       0.007487
# variety         0.007151
# modification    0.005933
# form            0.005811
# case            0.005633
# period          0.005476
# distinct        0.005244
# intermediate    0.005176
# dtype: float64
#
# Top distinctive words in health.txt compared to BSA handbook:
# work        0.011705
# muscle      0.010830
# exercise    0.008572
# chest       0.008076
# would       0.006465
# weight      0.005399
# man         0.005076
# arm         0.004831
# well        0.004808
# daily       0.004633
# dtype: float64
#
# Top distinctive words in knots.txt compared to BSA handbook:
# fig             0.089515
# knot            0.078723
# rope            0.057140
# hitch           0.031348
# strand          0.027621
# end             0.021751
# splice          0.020932
# illustration    0.019319
# bight           0.014308
# loop            0.012545
# dtype: float64
#
# Top distinctive words in leadership.txt compared to BSA handbook:
# leader          0.019520
# men             0.016916
# man             0.011243
# leadership      0.009293
# work            0.007907
# discipline      0.006509
# individual      0.006115
# instinct        0.005853
# spirit          0.005400
# organization    0.005343
# dtype: float64
#
# Top distinctive words in survival.txt compared to BSA handbook:
# could      0.011850
# friday     0.009515
# upon       0.009273
# would      0.008340
# shore      0.008190
# thought    0.006596
# might      0.006156
# ship       0.005639
# came       0.005596
# boat       0.004896
# dtype: float64

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\Drew Perschon
# ['.anaconda', '.conda', '.condarc', '.continuum', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jdks', '.jupyter', '.lesshst', '.m2', '.matplotlib', '.pybaseball', '.ssh', '.viminfo', '.viminfo.tmp', 'anaconda3', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'coolle', 'Documents', 'Downloads', 'Favorites', 'homework-3-drewperschon', 'homework-4-drewperschon', 'IdeaProjects', 'IntelGraphicsProfiles', 'Links', 'Local Settings', 'mlb_2023_team_stats.csv', 'mlb_wins.ipynb', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TM.blf', 'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'PrintHood', 'PyCharmMiscProject', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'testing', 'testing.ipynb', 'Untitled.ipynb', 'untitled.py', 'untitled.txt', 'untitled1.txt', 'Videos']
